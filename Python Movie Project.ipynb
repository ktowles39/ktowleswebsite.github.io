# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

#Brining in Data

df = pd.read_csv(r'C:\Users\ktowles\Downloads\movies.csv')
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Looking At Data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#Checking if There is any missing data with loops

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
#Checking Data Types for Colums

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
##Changing Data Type of Columns //did not work for some reason//

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[7], line 3
#       1 ##Changing Data Type of Columns
# ----> 3 df['budget'] = df['budget'].astype('int64')
#       4 df['gross'] = df['gross'].astype('int64')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# ...

# %%
#Correcting Years

df['yearcorrect'] = df['released'].astype(str).str[:4]

df.head()
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#Sorting by gross value

df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name  rating  genre  year  \
# 5445                                      Avatar       5      0  2009
# 7445                           Avengers: Endgame       5      0  2019
# 3045                                     Titanic       5      6  1997
# 6663  Star Wars: Episode VII - The Force Awakens       5      0  2015
# 7244                      Avengers: Infinity War       5      0  2018
# ...                                          ...     ...    ...   ...
# 7663                                More to Life      -1      6  2020
# 7664                                 Dream Round      -1      4  2020
# 7665                               Saving Mbango      -1      6  2020
# 7666                                It's Just Us      -1      6  2020
# 7667                                   Tee em el      -1     10  2020
#
#       released  score      votes  director  writer  star  country  \
# ...

# %%
#Creating Scatter Plot to See Correlations Between Budget and Gross Revenue

plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross Revenue')

plt.xlabel('Gross')
plt.ylabel ('Budget')
plt.show()

# %%
df.head()
# Out:
#                                              name  rating  genre  year  \
# 0                                     The Shining       6      6  1980
# 1                                 The Blue Lagoon       6      1  1980
# 2  Star Wars: Episode V - The Empire Strikes Back       4      0  1980
# 3                                       Airplane!       4      4  1980
# 4                                      Caddyshack       6      4  1980
#
#    released  score      votes  director  writer  star  country      budget  \
# 0      1705    8.4   927000.0      2589    4014  1047       54  19000000.0
# 1      1492    5.8    65000.0      2269    1632   327       55   4500000.0
# 2      1771    8.7  1200000.0      1111    2567  1745       55  18000000.0
# 3      1492    7.7   221000.0      1301    2000  2246       55   3500000.0
# 4      1543    7.3   108000.0      1054     521   410       55   6000000.0
#
#          gross  company  runtime  yearcorrect
# ...

# %%
#Doing Regression Analysis with colors

sns.regplot(x='budget', y ='gross', data=df, scatter_kws={"color":"blue"}, line_kws={"color":"red"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
#Checking Correlation
df.corr()
# Out:
# C:\Users\ktowles\AppData\Local\Temp\ipykernel_1012\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
#Looking at Companies and assigning a number to each Company

df_assign = df

for col_name in df_assign.columns:
    if (df_assign[col_name].dtype == 'object'):
        df_assign[col_name]= df_assign[col_name].astype('category')
        df_assign[col_name]= df_assign[col_name].cat.codes
        
df_assign.head()
# Out:
#                                              name  rating  genre  year  \
# 0                                     The Shining       6      6  1980
# 1                                 The Blue Lagoon       6      1  1980
# 2  Star Wars: Episode V - The Empire Strikes Back       4      0  1980
# 3                                       Airplane!       4      4  1980
# 4                                      Caddyshack       6      4  1980
#
#    released  score      votes  director  writer  star  country      budget  \
# 0      1705    8.4   927000.0      2589    4014  1047       54  19000000.0
# 1      1492    5.8    65000.0      2269    1632   327       55   4500000.0
# 2      1771    8.7  1200000.0      1111    2567  1745       55  18000000.0
# 3      1492    7.7   221000.0      1301    2000  2246       55   3500000.0
# 4      1543    7.3   108000.0      1054     521   410       55   6000000.0
#
#          gross  company  runtime  yearcorrect
# ...

# %%
df.head()
# Out:
#                                                 name  rating  genre  year  \
# 0                                        The Shining       6      6  1980
# 1                                    The Blue Lagoon       6      1  1980
# 2     Star Wars: Episode V - The Empire Strikes Back       4      0  1980
# 3                                          Airplane!       4      4  1980
# 4                                         Caddyshack       6      4  1980
# ...                                              ...     ...    ...   ...
# 7663                                    More to Life      -1      6  2020
# 7664                                     Dream Round      -1      4  2020
# 7665                                   Saving Mbango      -1      6  2020
# 7666                                    It's Just Us      -1      6  2020
# 7667                                       Tee em el      -1     10  2020
#
#       released  score      votes  director  writer  star  country      budget  \
# ...

# %%
df.head()
# Out:
#                                                 name  rating  genre  year  \
# 0                                        The Shining       6      6  1980
# 1                                    The Blue Lagoon       6      1  1980
# 2     Star Wars: Episode V - The Empire Strikes Back       4      0  1980
# 3                                          Airplane!       4      4  1980
# 4                                         Caddyshack       6      4  1980
# ...                                              ...     ...    ...   ...
# 7663                                    More to Life      -1      6  2020
# 7664                                     Dream Round      -1      4  2020
# 7665                                   Saving Mbango      -1      6  2020
# 7666                                    It's Just Us      -1      6  2020
# 7667                                       Tee em el      -1     10  2020
#
#       released  score      votes  director  writer  star  country      budget  \
# ...

# %%
correlation_matrix = df_assign.corr()

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()
# Out:
# C:\Users\ktowles\AppData\Local\Temp\ipykernel_1012\2450096846.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df_assign.corr()

# %%
df_assign.corr()
# Out:
# C:\Users\ktowles\AppData\Local\Temp\ipykernel_1012\635692427.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_assign.corr()
#                rating     genre      year  released     score     votes  \
# rating       1.000000  0.072423  0.008779  0.016613 -0.001314  0.033225
# genre        0.072423  1.000000 -0.081261  0.029822  0.027965 -0.145307
# year         0.008779 -0.081261  1.000000 -0.000695  0.097995  0.222945
# released     0.016613  0.029822 -0.000695  1.000000  0.042788  0.016097
# score       -0.001314  0.027965  0.097995  0.042788  1.000000  0.409182
# votes        0.033225 -0.145307  0.222945  0.016097  0.409182  1.000000
# director     0.019483 -0.015258 -0.020795 -0.001478  0.009559  0.000260
# writer      -0.005921  0.006567 -0.008656 -0.002404  0.019416  0.000892
# ...

# %%
#Unsatacking

correlation_matrix = df_assign.corr()

corr_pairs = correlation_matrix.unstack()

corr_pairs
# Out:
# C:\Users\ktowles\AppData\Local\Temp\ipykernel_1012\821106356.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df_assign.corr()
# rating       rating         1.000000
#              genre          0.072423
#              year           0.008779
#              released       0.016613
#              score         -0.001314
#                               ...
# yearcorrect  budget         0.015682
#              gross          0.002946
#              company       -0.010726
#              runtime        0.000410
#              yearcorrect    1.000000
# Length: 225, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
# Out:
# genre        budget        -0.356564
# budget       genre         -0.356564
# gross        genre         -0.235650
# genre        gross         -0.235650
# budget       rating        -0.176002
#                               ...
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# Length: 225, dtype: float64

# %%
#Checking which pairs have high correlation

strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.5]

print(strong_pairs)
# Out:
# votes        gross          0.630757
# gross        votes          0.630757
# budget       gross          0.740395
# gross        budget         0.740395
# released     yearcorrect    0.993694
# yearcorrect  released       0.993694
# rating       rating         1.000000
# writer       writer         1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64
